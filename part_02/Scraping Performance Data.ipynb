# %% [markdown]
# ## Scraping Hockey Reference

# %% [markdown]
# #### Workflow
#
# - I need to scrape several years of data for each team and all individual players
# - The team and player statistics will be in separate dataframes.
# - Aditionally, each year of data will also be in separate dataframes.
# - I will set up my scraper to grab team statistics for each team in a given year and make that a temporary dataframe which I will turn into individual csvs.
# - The individual player statistics will also be separated by year and saved into individual csvs.

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import urllib3
import requests
import time
import re

# %% [markdown]
# #### Creating base URL

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
base_url = 'https://www.hockey-reference.com/teams/'

# %% [markdown]
# #### Function to grab a txt file of team links

# %%
def get_page(url):
    page = urlopen(base_url)
    soup = BeautifulSoup(page, 'lxml')
    file = open('hockey-reference_urls.txt', 'w')
    file.write(str(soup))
    file.close()

def get_team_links(url):
    page = urlopen(url)
    soup = BeautifulSoup(page, 'lxml')

# %%
get_page(base_url)

# %%
with open('hockey-reference_urls.txt', 'r') as file:
    for line in file:
        line = line.strip()

# %%
page = open("hockey-reference_urls.txt", 'r')
soup = BeautifulSoup(page, "lxml")
div = soup.find('div', {'class': 'overthrow table_container'})

# %% [markdown]
# #### Saving the team links in a variable

# %%
team_links = []
links = div.find_all('a')
for link in links:
    team_links.append(link.get('href'))
# As teams have moved and changed over the years
# I had to manually add Arizona and Atlanta to this list
team_links.insert(1, '/teams/ARI/')
team_links.insert(2, '/teams/ATL/')

# %%
team_links
# Out:
# ['/teams/ANA/',
#  '/teams/ARI/',
#  '/teams/ATL/',
#  '/teams/PHX/',
#  '/teams/BOS/',
#  '/teams/BUF/',
#  '/teams/CGY/',
#  '/teams/CAR/',
#  '/teams/CHI/',
#  '/teams/COL/',
#  '/teams/CBJ/',
#  '/teams/DAL/',
#  '/teams/DET/',
#  '/teams/EDM/',
#  '/teams/FLA/',
#  '/teams/LAK/',
#  '/teams/MIN/',
#  '/teams/MTL/',
#  '/teams/NSH/',
#  '/teams/NJD/',
#  '/teams/NYI/',
#  '/teams/NYR/',
#  '/teams/OTT/',
#  '/teams/PHI/',
#  '/teams/PIT/',
#  '/teams/SJS/',
#  '/teams/STL/',
#  '/teams/TBL/',
#  '/teams/TOR/',
#  '/teams/VAN/',
#  '/teams/VEG/',
#  '/teams/WSH/',
#  '/teams/WPG/']

# %% [markdown]
# ### Function for scraping individual player data
#
# - This function finds a specific table on each teams page which contains individual player stats for a given year.
# - There will be a for loop later which will call this function and iterate through each team and each year.

# %%
def get_player_table(url):
    res = requests.get(url)
    skater_soup = BeautifulSoup(res.content, 'lxml')
    team_name = skater_soup.find('h1', {'itemprop': 'name'}).find_all('span')[1].text
    table = skater_soup.find('div', {'id': 'all_skaters'}).find('table', {'id': 'skaters'}).find('tbody')
    player_stats = []
    for row in table.find_all('tr'):
        players = {}
        for element in row:
            players['Player'] = row.find('a').text
            players['Age'] = row.find('td', {'data-stat': 'age'}).text
            players['Position'] = row.find('td', {'data-stat': 'pos'}).text
            players['Games Played'] = row.find('td', {'data-stat': 'games_played'}).text
            players['Goals'] = row.find('td', {'data-stat': 'goals'}).text
            players['Assists'] = row.find('td', {'data-stat': 'assists'}).text
            players['Points'] = row.find('td', {'data-stat': 'points'}).text
            players['Plus Minus'] = row.find('td', {'data-stat': 'plus_minus'}).text
            players['Penalty Minutes'] = row.find('td', {'data-stat': 'pen_min'}).text
            players['ES Goals'] = row.find('td', {'data-stat': 'goals_ev'}).text
            players['PP Goals'] = row.find('td', {'data-stat': 'goals_pp'}).text
            players['SH Goals'] = row.find('td', {'data-stat': 'goals_sh'}).text
            players['GW Goals'] = row.find('td', {'data-stat': 'goals_gw'}).text
            players['ES Assists'] = row.find('td', {'data-stat': 'assists_ev'}).text
            players['PP Assists'] = row.find('td', {'data-stat': 'assists_pp'}).text
            players['SH Assists'] = row.find('td', {'data-stat': 'assists_sh'}).text
            players['Shots'] = row.find('td', {'data-stat': 'shots'}).text
            players['Shooting Perecentage'] = row.find('td', {'data-stat': 'shot_pct'}).text
            players['Time on Ice'] = row.find('td', {'data-stat': 'time_on_ice'}).text
            players['Time on Ice Avg'] = row.find('td', {'data-stat': 'time_on_ice_avg'}).text
            players['Offenisve Point Shares'] = row.find('td', {'data-stat': 'ops'}).text
            players['Defensive Point Shares'] = row.find('td', {'data-stat': 'dps'}).text
            players['Point Shares'] = row.find('td', {'data-stat': 'ps'}).text
            players['ES Blocks'] = row.find('td', {'data-stat': 'blocks'}).text
            players['ES Hits'] = row.find('td', {'data-stat': 'hits'}).text
            players['ES Face-Off Wins'] = row.find('td', {'data-stat': 'faceoff_wins'}).text
            players['ES Face-Off Losses'] = row.find('td', {'data-stat': 'faceoff_losses'}).text
            players['ES Face-Off Pct'] = row.find('td', {'data-stat': 'faceoff_percentage'}).text
            players['Team'] = team_name
        player_stats.append(players)
    return player_stats

# %% [markdown]
# ### Function for scraping team statistics
#
# - This function finds a specific table on each teams page
# - I had to get creative in scraping this table as the data in this table was formatted differently than the individual player data table.
# - Once I find the specific table within the "team_soup" variable, this function uses the dictionary structure of the data to assign column names
# - Again this function will be called later in a for loop to iterate through team and year. Each year will get its own csv file.

# %%
def get_team_table(url):
    res = requests.get(url)
    team_soup = BeautifulSoup(res.content, 'lxml')
    team_name = team_soup.find('h1', {'itemprop': 'name'}).find_all('span')[1].text
    table = team_soup.find('div', {'id': 'all_team_stats'}).find('table', {'id': 'team_stats'})
    team_list = []
    team = {'team': team_name}
    for row in table.find('tbody').find('tr').find_all('td'):
        stat = row.text
        temp = row.attrs
        column = temp['data-stat']
        team.update({column: stat})
    team_list.append(team)
    return team_list

# %% [markdown]
# ### Function for scraping year results data
#
# - This scrape will get me the finishing results for each team for each year.
# - Eventually this will be combined with the team statistics data for modeling purposes

# %%
url = 'https://www.hockey-reference.com/leagues/NHL_2018.html'
def get_league_season(url):
    res = requests.get(url).content
    res = res.decode('utf-8')
    season_soup = BeautifulSoup(re.sub('<!--|-->', '', res), 'lxml')
    table = season_soup.find('div', {'id': 'div_stats'}).find('tbody')
    league_season = []
    for row in table.find_all('tr'):
        season = {}
        for element in row.find_all('td'):
            stat = element.text
            temp = element.attrs
            column = temp['data-stat']
            season.update({column: stat})
        league_season.append(season)
    league_season = pd.DataFrame(league_season)
    cols=[i for i in league_season.columns if i not in ['team_name']]
    for col in cols:
        league_season[col]=pd.to_numeric(league_season[col])
    return league_season

# %%
league_season_2000 = get_league_season('https://www.hockey-reference.com/leagues/NHL_2000.html')

# %%
league_season_2000.to_csv('2000 league season.csv')

# %%
league_url = 'https://www.hockey-reference.com/leagues/'
links = ['NHL_2007.html', 'NHL_2008.html', 'NHL_2009.html', 'NHL_2010.html', 
         'NHL_2011.html', 'NHL_2012.html', 'NHL_2013.html', 'NHL_2014.html',
         'NHL_2015.html', 'NHL_2016.html', 'NHL_2017.html', 'NHL_2018.html']
years = ['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
         '2015', '2016', '2017', '2018']

for link in links:
    url = league_url + link
    league_year = get_league_season(url)
    years = ['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
             '2015', '2016', '2017', '2018']
    for year in years:
        time.sleep(3)
# Out:
#   File "<ipython-input-66-fbea6b67b5b7>", line 14
#     pd.DataFrame(year + '_league_season') = league_year
#     ^
# SyntaxError: can't assign to function call

# %%
get_league_season('https://www.hockey-reference.com/leagues/NHL_2018.html')
# Out:
#     average_age  chances_pp  games  goals  goals_against_ev  goals_ev  \
# 0          28.4         274     82    267               145       193
# 1          26.8         274     82    277               159       200
# 2          27.5         276     82    296               172       216
# 3          28.6         258     82    270               161       197
# 4          28.0         248     82    272               182       218
# 5          28.4         244     82    259               178       197
# 6          28.3         224     82    277               189       213
# 7          28.7         214     82    235               159       183
# 8          29.5         240     82    253               176       194
# 9          27.7         260     82    272               195       198
# 10         28.8         257     82    252               191       188
# 11         27.4         261     82    251               176       196
# 12         29.1         240     82    239               159       183
# 13         26.4         227     82    242               170       195
# 14         27.7         252     82    248               190       178
# 15         27.8         249     82    248               193       188
# 16         26.4         296     82    257               183       188
# 17         28.5         246     82    226               166       180
# 18         28.5         244     82    235               158       177
# 19         28.4         269     82    218               187       166
# 20         27.0         239     82    228               204       178
# 21         28.4         250     82    264               219       198
# 22         26.8         210     82    234               200       187
# 23         28.7         241     82    231               212       172
# 24         28.0         269     82    229               198       180
# 25         28.2         247     82    218               189       158
# 26         30.2         234     82    217               191       162
# 27         27.8         244     82    209               184       148
# 28         26.5         243     82    208               195       163
# 29         29.3         248     82    221               222       174
# 30         27.1         257     82    199               216       140
#
#     goals_pp  goals_sh  losses  losses_ot      ...        save_pct  shot_pct  \
# 0         58        10      18         11      ...           0.923       9.9
# 1         64         9      20         10      ...           0.917      10.3
# 2         66         9      23          5      ...           0.912      10.7
# 3         61         9      20         12      ...           0.912       9.9
# 4         53         8      24          7      ...           0.911      10.1
# 5         55         4      26          7      ...           0.909      10.7
# 6         56         4      26          7      ...           0.915      10.1
# 7         38        10      25         13      ...           0.923       9.3
# 8         49         7      26         11      ...           0.910      10.0
# 9         68         6      29          6      ...           0.902       9.6
# 10        53         8      27         10      ...           0.909       9.1
# 11        54         3      26         14      ...           0.903       9.5
# 12        49         5      29          8      ...           0.920       9.3
# 13        39         4      30          7      ...           0.912       8.5
# 14        54        12      29          9      ...           0.908       9.3
# 15        47        10      30          8      ...           0.914       8.7
# 16        65         7      30          9      ...           0.914      10.5
# 17        38         5      32          6      ...           0.909       8.3
# 18        47         7      32          8      ...           0.909       9.0
# 19        43         7      35         10      ...           0.905       7.8
# 20        44         3      35         11      ...           0.893       8.1
# 21        58         5      37         10      ...           0.900      10.1
# 22        31        11      40          6      ...           0.901       8.4
# 23        51         5      39          9      ...           0.909       9.0
# 24        43         5      39         10      ...           0.906       8.2
# 25        53         7      40         11      ...           0.902       8.8
# 26        41         9      39         13      ...           0.903       8.5
# 27        52         7      40         13      ...           0.903       7.7
# 28        41         2      41         12      ...           0.905       8.4
# 29        41         4      43         11      ...           0.895       8.7
# 30        49         9      45         12      ...           0.896       7.7
#
#     shots  shots_against   sos   srs               team_name  \
# 0    2641           2659  0.03  0.71    Nashville Predators*
# 1    2643           2613  0.02  0.74          Winnipeg Jets*
# 2    2737           2756 -0.07  0.66    Tampa Bay Lightning*
# 3    2703           2399 -0.07  0.62          Boston Bruins*
# 4    2774           2619 -0.01  0.52   Vegas Golden Knights*
# 5    2400           2637 -0.04  0.21    Washington Capitals*
# 6    2700           2844 -0.06  0.49    Toronto Maple Leafs*
# 7    2475           2716  0.01  0.24          Anaheim Ducks*
# 8    2506           2595  0.04  0.29         Minnesota Wild*
# 9    2845           2575 -0.04  0.23    Pittsburgh Penguins*
# 10   2744           2521  0.00  0.28        San Jose Sharks*
# 11   2683           2506 -0.03  0.07    Philadelphia Flyers*
# 12   2544           2537  0.00  0.44      Los Angeles Kings*
# 13   2796           2612 -0.04  0.11  Columbus Blue Jackets*
# 14   2626           2654 -0.03  0.02      New Jersey Devils*
# 15   2822           2838 -0.04 -0.01        Florida Panthers
# 16   2489           2809  0.04  0.28     Colorado Avalanche*
# 17   2677           2438  0.05  0.10         St. Louis Blues
# 18   2560           2447  0.04  0.17            Dallas Stars
# 19   2759           2554  0.03 -0.33          Calgary Flames
# 20   2780           2367 -0.01 -0.35     Carolina Hurricanes
# 21   2572           2918 -0.01 -0.40      New York Islanders
# 22   2740           2634  0.03 -0.32         Edmonton Oilers
# 23   2538           2898 -0.01 -0.46        New York Rangers
# 24   2793           2697  0.07 -0.26      Chicago Blackhawks
# 25   2464           2641  0.05 -0.51       Vancouver Canucks
# 26   2490           2613 -0.01 -0.48       Detroit Red Wings
# 27   2687           2650  0.00 -0.68      Montreal Canadiens
# 28   2450           2642  0.05 -0.53         Arizona Coyotes
# 29   2515           2712  0.00 -0.85         Ottawa Senators
# 30   2557           2681  0.01 -0.98          Buffalo Sabres
#
#     total_goals_per_game  wins  wins_shootout
# 0                   5.83    53              6
# 1                   6.04    52              4
# 2                   6.49    54              6
# 3                   5.90    50              3
# 4                   6.10    51              4
# 5                   6.07    49              3
# 6                   6.21    49              7
# 7                   5.50    44              4
# 8                   5.91    45              3
# 9                   6.37    47              2
# 10                  5.87    45              5
# 11                  6.02    42              2
# 12                  5.39    45              2
# 13                  5.76    45              6
# 14                  6.00    44              5
# 15                  6.02    44              3
# 16                  6.02    43              2
# 17                  5.46    44              3
# 18                  5.61    42              4
# 19                  5.68    37              2
# 20                  5.90    36              3
# 21                  6.83    35              3
# 22                  6.06    36              5
# 23                  6.09    34              3
# 24                  5.91    33              1
# 25                  5.88    31              0
# 26                  5.76    30              5
# 27                  5.77    29              2
# 28                  5.66    29              2
# 29                  6.24    28              2
# 30                  5.84    25              1
#
# [31 rows x 32 columns]

# %%
url = 'https://www.hockey-reference.com/leagues'

# %%
get_league_season('https://www.hockey-reference.com/leagues/NHL_2018.html')
# Out:
# {'team_name': 'Buffalo Sabres',
#  'average_age': '27.1',
#  'games': '82',
#  'wins': '25',
#  'losses': '45',
#  'losses_ot': '12',
#  'points': '62',
#  'points_pct': '.378',
#  'goals': '199',
#  'opp_goals': '280',
#  'wins_shootout': '1',
#  'losses_shootout': '2',
#  'srs': '-0.98',
#  'sos': '0.01',
#  'total_goals_per_game': '5.84',
#  'goals_ev': '140',
#  'goals_against_ev': '216',
#  'goals_pp': '49',
#  'chances_pp': '257',
#  'power_play_pct': '19.07',
#  'opp_goals_pp': '52',
#  'opp_chances_pp': '235',
#  'pen_kill_pct': '77.87',
#  'goals_sh': '9',
#  'opp_goals_sh': '10',
#  'pen_min_per_game': '8.2',
#  'pen_min_per_game_opp': '8.8',
#  'shots': '2557',
#  'shot_pct': '7.7',
#  'shots_against': '2681',
#  'save_pct': '.896',
#  'pdo': '98.0'}

# %%
league_season.dtypes
# Out:
# average_age             float64
# chances_pp                int64
# games                     int64
# goals                     int64
# goals_against_ev          int64
# goals_ev                  int64
# goals_pp                  int64
# goals_sh                  int64
# losses                    int64
# losses_ot                 int64
# losses_shootout           int64
# opp_chances_pp            int64
# opp_goals                 int64
# opp_goals_pp              int64
# opp_goals_sh              int64
# pdo                     float64
# pen_kill_pct            float64
# pen_min_per_game        float64
# pen_min_per_game_opp    float64
# points                    int64
# points_pct              float64
# power_play_pct          float64
# save_pct                float64
# shot_pct                float64
# shots                     int64
# shots_against             int64
# sos                     float64
# srs                     float64
# team_name                object
# total_goals_per_game    float64
# wins                      int64
# wins_shootout             int64
# dtype: object

# %% [markdown]
# - These cells were used for testing on individual web pages
# - I saved the function calls as universal functions

# %%
team_year = get_team_table('https://www.hockey-reference.com/teams/ANA/2018.html')

# %%
player_year = get_player_table('https://www.hockey-reference.com/teams/ANA/2018.html')

# %%
league_season = get_team_season('https://www.hockey-reference.com/leagues/NHL_2018.html')

# %% [markdown]
# ### For loop for scraping team statistic data
#
# - Because I need each year to be separate, I am manually calling each year in the loop which will be temporarily saved in a dataframe. Then that dataframe will be converted to a csv. Each csv will get its own dataframe name in a separate EDA notebook.

# %%
base_url = 'https://www.hockey-reference.com'
teams = team_links
years = ['2007.html']
year_df = pd.DataFrame()
for team in teams:
    try:
        for year in years:
            url = base_url + team + year
            team_year = get_team_table(url)
            team_df = pd.DataFrame(team_year)
            year_df = pd.concat([year_df, team_df], axis=0)
            year_df.reset_index(drop=True, inplace=True)
            cols=[i for i in year_df.columns if i not in ['team']]
            for col in cols:
                year_df[col]=pd.to_numeric(year_df[col])
            time.sleep(3)               
    except:
        continue

# %%
# The Phoenix Coyotes changed their name to the Arizona Coyotes in 2016.
# My scraper was giving me dual entries for this team in a few years.
# This cell was used to remove the duplicate information before saving to csv.

year_df.drop([2], axis=0, inplace=True)
year_df.reset_index(drop=True, inplace=True)

# %%
year_df.head()

# %% [markdown]
# ### Saving to CSV
#
# - Again each year was saved independently

# %%
year_df.to_csv('2007 team stats.csv')

# %% [markdown]
# ### For loop for scraping individual player stats
#
# - Similar to the previous for loop, this will output one year of data which will be saved to csv.

# %%
base_url = 'https://www.hockey-reference.com/leagues'
years = ['NHL_2018.html']
league_year = pd.DataFrame()
for year in years:
    try:
        url = base_url + year
        league_season = get_team_table(url)
        team_df = pd.DataFrame(league_season)
        year_player_stats = pd.concat([year_df, team_df], axis=0)
        year_player_stats.reset_index(drop=True, inplace=True)
        time.sleep(3)
    except:
        continue

# %%
year_player_stats

# %% [markdown]
# ### Saving to CSV
#
# - Again each year will be saved to csv. This csv will contain stats for every player in the league for that year.

# %%
year_df.to_csv('2011 skater stats.csv')

# %% [markdown]
# ### For lop for scraping league year stats

# %%
base_url = 'https://www.hockey-reference.com'
teams = team_links
years = ['2007.html']
year_df = pd.DataFrame()
for team in teams:
    try:
        for year in years:
            url = base_url + team + year
            team_year = get_team_table(url)
            team_df = pd.DataFrame(team_year)
            year_df = pd.concat([year_df, team_df], axis=0)
            year_df.reset_index(drop=True, inplace=True)
            cols=[i for i in year_df.columns if i not in ['team']]
            for col in cols:
                year_df[col]=pd.to_numeric(year_df[col])
            time.sleep(3)               
    except:
        continue

# %%
base_url = 'https://www.hockey-reference.com/leagues/NHL_2018.html'
def get_playoff_results(url):
    res = requests.get(url).content
    res = res.decode('utf-8')
    playoff_soup = BeautifulSoup(re.sub('<!--|-->', '', res), 'lxml')
    table = playoff_soup.find('div', {'id': 'div_all_playoffs'}).find('table', {'id': 'all_playoffs'})
    for row in table.find_all('tr'):
        for element in row.find('td'):
            print(element)
#         for element in row.find_all('td')[0:1]:
#             print(element.text)

# %%
get_playoff_results('https://www.hockey-reference.com/leagues/NHL_2018.html')
# Out:
# <span class="tooltip opener" data-id="s15">Stanley Cup Final</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201805280VEG.html">Game 1, May 28</a></td>
# <td>May 28</td>
# <td>Washington Capitals</td>
# <td class="center">4</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">6</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805300VEG.html">Game 2, May 30</a></td>
# <td>May 30</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">3</td>
# <td>Vegas Golden Knights</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201806020WSH.html">Game 3, June 2</a></td>
# <td>June 2</td>
# <td>Vegas Golden Knights</td>
# <td class="center">1</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">3</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201806040WSH.html">Game 4, June 4</a></td>
# <td>June 4</td>
# <td>Vegas Golden Knights</td>
# <td class="center">2</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">6</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201806070VEG.html">Game 5, June 7</a></td>
# <td>June 7</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">4</td>
# <td>Vegas Golden Knights</td>
# <td class="center">3</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201805280VEG.html">Game 1, May 28</a>
# <a href="/boxscores/201805300VEG.html">Game 2, May 30</a>
# <a href="/boxscores/201806020WSH.html">Game 3, June 2</a>
# <a href="/boxscores/201806040WSH.html">Game 4, June 4</a>
# <a href="/boxscores/201806070VEG.html">Game 5, June 7</a>
#
# <span class="tooltip opener" data-id="s14">Conference Finals</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201805120WPG.html">Game 1, May 12</a></td>
# <td>May 12</td>
# <td>Vegas Golden Knights</td>
# <td class="center">2</td>
# <td class="winner">Winnipeg Jets</td>
# <td class="center winner">4</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805140WPG.html">Game 2, May 14</a></td>
# <td>May 14</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">3</td>
# <td>Winnipeg Jets</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805160VEG.html">Game 3, May 16</a></td>
# <td>May 16</td>
# <td>Winnipeg Jets</td>
# <td class="center">2</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">4</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805180VEG.html">Game 4, May 18</a></td>
# <td>May 18</td>
# <td>Winnipeg Jets</td>
# <td class="center">2</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">3</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805200WPG.html">Game 5, May 20</a></td>
# <td>May 20</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">2</td>
# <td>Winnipeg Jets</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201805120WPG.html">Game 1, May 12</a>
# <a href="/boxscores/201805140WPG.html">Game 2, May 14</a>
# <a href="/boxscores/201805160VEG.html">Game 3, May 16</a>
# <a href="/boxscores/201805180VEG.html">Game 4, May 18</a>
# <a href="/boxscores/201805200WPG.html">Game 5, May 20</a>
# <span class="tooltip opener" data-id="s13">Conference Finals</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201805110TBL.html">Game 1, May 11</a></td>
# <td>May 11</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">4</td>
# <td>Tampa Bay Lightning</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805130TBL.html">Game 2, May 13</a></td>
# <td>May 13</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">6</td>
# <td>Tampa Bay Lightning</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805150WSH.html">Game 3, May 15</a></td>
# <td>May 15</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">4</td>
# <td>Washington Capitals</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805170WSH.html">Game 4, May 17</a></td>
# <td>May 17</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">4</td>
# <td>Washington Capitals</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805190TBL.html">Game 5, May 19</a></td>
# <td>May 19</td>
# <td>Washington Capitals</td>
# <td class="center">2</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">3</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805210WSH.html">Game 6, May 21</a></td>
# <td>May 21</td>
# <td>Tampa Bay Lightning</td>
# <td class="center">0</td>
# <td>Washington Capitals</td>
# <td class="center">3</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805230TBL.html">Game 7, May 23</a></td>
# <td>May 23</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">4</td>
# <td>Tampa Bay Lightning</td>
# <td class="center">0</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201805110TBL.html">Game 1, May 11</a>
# <a href="/boxscores/201805130TBL.html">Game 2, May 13</a>
# <a href="/boxscores/201805150WSH.html">Game 3, May 15</a>
# <a href="/boxscores/201805170WSH.html">Game 4, May 17</a>
# <a href="/boxscores/201805190TBL.html">Game 5, May 19</a>
# <a href="/boxscores/201805210WSH.html">Game 6, May 21</a>
# <a href="/boxscores/201805230TBL.html">Game 7, May 23</a>
#
# <span class="tooltip opener" data-id="s12">Second Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804270NSH.html">Game 1, April 27</a></td>
# <td>April 27</td>
# <td class="winner">Winnipeg Jets</td>
# <td class="center winner">4</td>
# <td>Nashville Predators</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804290NSH.html">Game 2, April 29</a></td>
# <td>April 29</td>
# <td>Winnipeg Jets</td>
# <td class="center">4</td>
# <td class="winner">Nashville Predators</td>
# <td class="center winner">5</td>
# <td class="center">
#
# 			(2OT)
#
# 		</td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805010WPG.html">Game 3, May 1</a></td>
# <td>May 1</td>
# <td>Nashville Predators</td>
# <td class="center">4</td>
# <td class="winner">Winnipeg Jets</td>
# <td class="center winner">7</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805030WPG.html">Game 4, May 3</a></td>
# <td>May 3</td>
# <td class="winner">Nashville Predators</td>
# <td class="center winner">2</td>
# <td>Winnipeg Jets</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805050NSH.html">Game 5, May 5</a></td>
# <td>May 5</td>
# <td class="winner">Winnipeg Jets</td>
# <td class="center winner">6</td>
# <td>Nashville Predators</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805070WPG.html">Game 6, May 7</a></td>
# <td>May 7</td>
# <td class="winner">Nashville Predators</td>
# <td class="center winner">4</td>
# <td>Winnipeg Jets</td>
# <td class="center">0</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805100NSH.html">Game 7, May 10</a></td>
# <td>May 10</td>
# <td class="winner">Winnipeg Jets</td>
# <td class="center winner">5</td>
# <td>Nashville Predators</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804270NSH.html">Game 1, April 27</a>
# <a href="/boxscores/201804290NSH.html">Game 2, April 29</a>
# <a href="/boxscores/201805010WPG.html">Game 3, May 1</a>
# <a href="/boxscores/201805030WPG.html">Game 4, May 3</a>
# <a href="/boxscores/201805050NSH.html">Game 5, May 5</a>
# <a href="/boxscores/201805070WPG.html">Game 6, May 7</a>
# <a href="/boxscores/201805100NSH.html">Game 7, May 10</a>
# <span class="tooltip opener" data-id="s11">Second Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804260VEG.html">Game 1, April 26</a></td>
# <td>April 26</td>
# <td>San Jose Sharks</td>
# <td class="center">0</td>
# <td>Vegas Golden Knights</td>
# <td class="center">7</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804280VEG.html">Game 2, April 28</a></td>
# <td>April 28</td>
# <td class="winner">San Jose Sharks</td>
# <td class="center winner">4</td>
# <td>Vegas Golden Knights</td>
# <td class="center">3</td>
# <td class="center">
#
# 			(2OT)
#
# 		</td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804300SJS.html">Game 3, April 30</a></td>
# <td>April 30</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">4</td>
# <td>San Jose Sharks</td>
# <td class="center">3</td>
# <td class="center">
#
# 			(OT)
#
# 		</td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805020SJS.html">Game 4, May 2</a></td>
# <td>May 2</td>
# <td>Vegas Golden Knights</td>
# <td class="center">0</td>
# <td>San Jose Sharks</td>
# <td class="center">4</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805040VEG.html">Game 5, May 4</a></td>
# <td>May 4</td>
# <td>San Jose Sharks</td>
# <td class="center">3</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">5</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805060SJS.html">Game 6, May 6</a></td>
# <td>May 6</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">3</td>
# <td>San Jose Sharks</td>
# <td class="center">0</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804260VEG.html">Game 1, April 26</a>
# <a href="/boxscores/201804280VEG.html">Game 2, April 28</a>
# <a href="/boxscores/201804300SJS.html">Game 3, April 30</a>
# <a href="/boxscores/201805020SJS.html">Game 4, May 2</a>
# <a href="/boxscores/201805040VEG.html">Game 5, May 4</a>
# <a href="/boxscores/201805060SJS.html">Game 6, May 6</a>
# <span class="tooltip opener" data-id="s10">Second Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804280TBL.html">Game 1, April 28</a></td>
# <td>April 28</td>
# <td class="winner">Boston Bruins</td>
# <td class="center winner">6</td>
# <td>Tampa Bay Lightning</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804300TBL.html">Game 2, April 30</a></td>
# <td>April 30</td>
# <td>Boston Bruins</td>
# <td class="center">2</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">4</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805020BOS.html">Game 3, May 2</a></td>
# <td>May 2</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">4</td>
# <td>Boston Bruins</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805040BOS.html">Game 4, May 4</a></td>
# <td>May 4</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">4</td>
# <td>Boston Bruins</td>
# <td class="center">3</td>
# <td class="center">
#
# 			(OT)
#
# 		</td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805060TBL.html">Game 5, May 6</a></td>
# <td>May 6</td>
# <td>Boston Bruins</td>
# <td class="center">1</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">3</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804280TBL.html">Game 1, April 28</a>
# <a href="/boxscores/201804300TBL.html">Game 2, April 30</a>
# <a href="/boxscores/201805020BOS.html">Game 3, May 2</a>
# <a href="/boxscores/201805040BOS.html">Game 4, May 4</a>
# <a href="/boxscores/201805060TBL.html">Game 5, May 6</a>
# <span class="tooltip opener" data-id="s9">Second Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804260WSH.html">Game 1, April 26</a></td>
# <td>April 26</td>
# <td class="winner">Pittsburgh Penguins</td>
# <td class="center winner">3</td>
# <td>Washington Capitals</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804290WSH.html">Game 2, April 29</a></td>
# <td>April 29</td>
# <td>Pittsburgh Penguins</td>
# <td class="center">1</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">4</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805010PIT.html">Game 3, May 1</a></td>
# <td>May 1</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">4</td>
# <td>Pittsburgh Penguins</td>
# <td class="center">3</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805030PIT.html">Game 4, May 3</a></td>
# <td>May 3</td>
# <td>Washington Capitals</td>
# <td class="center">1</td>
# <td class="winner">Pittsburgh Penguins</td>
# <td class="center winner">3</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805050WSH.html">Game 5, May 5</a></td>
# <td>May 5</td>
# <td>Pittsburgh Penguins</td>
# <td class="center">3</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">6</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201805070PIT.html">Game 6, May 7</a></td>
# <td>May 7</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">2</td>
# <td>Pittsburgh Penguins</td>
# <td class="center">1</td>
# <td class="center">
#
# 			(OT)
#
# 		</td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804260WSH.html">Game 1, April 26</a>
# <a href="/boxscores/201804290WSH.html">Game 2, April 29</a>
# <a href="/boxscores/201805010PIT.html">Game 3, May 1</a>
# <a href="/boxscores/201805030PIT.html">Game 4, May 3</a>
# <a href="/boxscores/201805050WSH.html">Game 5, May 5</a>
# <a href="/boxscores/201805070PIT.html">Game 6, May 7</a>
#
# <span class="tooltip opener" data-id="s8">First Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804110PIT.html">Game 1, April 11</a></td>
# <td>April 11</td>
# <td>Philadelphia Flyers</td>
# <td class="center">0</td>
# <td>Pittsburgh Penguins</td>
# <td class="center">7</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804130PIT.html">Game 2, April 13</a></td>
# <td>April 13</td>
# <td class="winner">Philadelphia Flyers</td>
# <td class="center winner">5</td>
# <td>Pittsburgh Penguins</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804150PHI.html">Game 3, April 15</a></td>
# <td>April 15</td>
# <td class="winner">Pittsburgh Penguins</td>
# <td class="center winner">5</td>
# <td>Philadelphia Flyers</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804180PHI.html">Game 4, April 18</a></td>
# <td>April 18</td>
# <td class="winner">Pittsburgh Penguins</td>
# <td class="center winner">5</td>
# <td>Philadelphia Flyers</td>
# <td class="center">0</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804200PIT.html">Game 5, April 20</a></td>
# <td>April 20</td>
# <td class="winner">Philadelphia Flyers</td>
# <td class="center winner">4</td>
# <td>Pittsburgh Penguins</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804220PHI.html">Game 6, April 22</a></td>
# <td>April 22</td>
# <td class="winner">Pittsburgh Penguins</td>
# <td class="center winner">8</td>
# <td>Philadelphia Flyers</td>
# <td class="center">5</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804110PIT.html">Game 1, April 11</a>
# <a href="/boxscores/201804130PIT.html">Game 2, April 13</a>
# <a href="/boxscores/201804150PHI.html">Game 3, April 15</a>
# <a href="/boxscores/201804180PHI.html">Game 4, April 18</a>
# <a href="/boxscores/201804200PIT.html">Game 5, April 20</a>
# <a href="/boxscores/201804220PHI.html">Game 6, April 22</a>
# <span class="tooltip opener" data-id="s7">First Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804120BOS.html">Game 1, April 12</a></td>
# <td>April 12</td>
# <td>Toronto Maple Leafs</td>
# <td class="center">1</td>
# <td class="winner">Boston Bruins</td>
# <td class="center winner">5</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804140BOS.html">Game 2, April 14</a></td>
# <td>April 14</td>
# <td>Toronto Maple Leafs</td>
# <td class="center">3</td>
# <td class="winner">Boston Bruins</td>
# <td class="center winner">7</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804160TOR.html">Game 3, April 16</a></td>
# <td>April 16</td>
# <td>Boston Bruins</td>
# <td class="center">2</td>
# <td class="winner">Toronto Maple Leafs</td>
# <td class="center winner">4</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804190TOR.html">Game 4, April 19</a></td>
# <td>April 19</td>
# <td class="winner">Boston Bruins</td>
# <td class="center winner">3</td>
# <td>Toronto Maple Leafs</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804210BOS.html">Game 5, April 21</a></td>
# <td>April 21</td>
# <td class="winner">Toronto Maple Leafs</td>
# <td class="center winner">4</td>
# <td>Boston Bruins</td>
# <td class="center">3</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804230TOR.html">Game 6, April 23</a></td>
# <td>April 23</td>
# <td>Boston Bruins</td>
# <td class="center">1</td>
# <td class="winner">Toronto Maple Leafs</td>
# <td class="center winner">3</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804250BOS.html">Game 7, April 25</a></td>
# <td>April 25</td>
# <td>Toronto Maple Leafs</td>
# <td class="center">4</td>
# <td class="winner">Boston Bruins</td>
# <td class="center winner">7</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804120BOS.html">Game 1, April 12</a>
# <a href="/boxscores/201804140BOS.html">Game 2, April 14</a>
# <a href="/boxscores/201804160TOR.html">Game 3, April 16</a>
# <a href="/boxscores/201804190TOR.html">Game 4, April 19</a>
# <a href="/boxscores/201804210BOS.html">Game 5, April 21</a>
# <a href="/boxscores/201804230TOR.html">Game 6, April 23</a>
# <a href="/boxscores/201804250BOS.html">Game 7, April 25</a>
# <span class="tooltip opener" data-id="s6">First Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804120WSH.html">Game 1, April 12</a></td>
# <td>April 12</td>
# <td class="winner">Columbus Blue Jackets</td>
# <td class="center winner">4</td>
# <td>Washington Capitals</td>
# <td class="center">3</td>
# <td class="center">
#
# 			(OT)
#
# 		</td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804150WSH.html">Game 2, April 15</a></td>
# <td>April 15</td>
# <td class="winner">Columbus Blue Jackets</td>
# <td class="center winner">5</td>
# <td>Washington Capitals</td>
# <td class="center">4</td>
# <td class="center">
#
# 			(OT)
#
# 		</td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804170CBJ.html">Game 3, April 17</a></td>
# <td>April 17</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">3</td>
# <td>Columbus Blue Jackets</td>
# <td class="center">2</td>
# <td class="center">
#
# 			(2OT)
#
# 		</td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804190CBJ.html">Game 4, April 19</a></td>
# <td>April 19</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">4</td>
# <td>Columbus Blue Jackets</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804210WSH.html">Game 5, April 21</a></td>
# <td>April 21</td>
# <td>Columbus Blue Jackets</td>
# <td class="center">3</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">4</td>
# <td class="center">
#
# 			(OT)
#
# 		</td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804230CBJ.html">Game 6, April 23</a></td>
# <td>April 23</td>
# <td class="winner">Washington Capitals</td>
# <td class="center winner">6</td>
# <td>Columbus Blue Jackets</td>
# <td class="center">3</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804120WSH.html">Game 1, April 12</a>
# <a href="/boxscores/201804150WSH.html">Game 2, April 15</a>
# <a href="/boxscores/201804170CBJ.html">Game 3, April 17</a>
# <a href="/boxscores/201804190CBJ.html">Game 4, April 19</a>
# <a href="/boxscores/201804210WSH.html">Game 5, April 21</a>
# <a href="/boxscores/201804230CBJ.html">Game 6, April 23</a>
# <span class="tooltip opener" data-id="s5">First Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804120TBL.html">Game 1, April 12</a></td>
# <td>April 12</td>
# <td>New Jersey Devils</td>
# <td class="center">2</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">5</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804140TBL.html">Game 2, April 14</a></td>
# <td>April 14</td>
# <td>New Jersey Devils</td>
# <td class="center">3</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">5</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804160NJD.html">Game 3, April 16</a></td>
# <td>April 16</td>
# <td>Tampa Bay Lightning</td>
# <td class="center">2</td>
# <td class="winner">New Jersey Devils</td>
# <td class="center winner">5</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804180NJD.html">Game 4, April 18</a></td>
# <td>April 18</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">3</td>
# <td>New Jersey Devils</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804210TBL.html">Game 5, April 21</a></td>
# <td>April 21</td>
# <td>New Jersey Devils</td>
# <td class="center">1</td>
# <td class="winner">Tampa Bay Lightning</td>
# <td class="center winner">3</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804120TBL.html">Game 1, April 12</a>
# <a href="/boxscores/201804140TBL.html">Game 2, April 14</a>
# <a href="/boxscores/201804160NJD.html">Game 3, April 16</a>
# <a href="/boxscores/201804180NJD.html">Game 4, April 18</a>
# <a href="/boxscores/201804210TBL.html">Game 5, April 21</a>
# <span class="tooltip opener" data-id="s4">First Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804120ANA.html">Game 1, April 12</a></td>
# <td>April 12</td>
# <td class="winner">San Jose Sharks</td>
# <td class="center winner">3</td>
# <td>Anaheim Ducks</td>
# <td class="center">0</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804140ANA.html">Game 2, April 14</a></td>
# <td>April 14</td>
# <td class="winner">San Jose Sharks</td>
# <td class="center winner">3</td>
# <td>Anaheim Ducks</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804160SJS.html">Game 3, April 16</a></td>
# <td>April 16</td>
# <td>Anaheim Ducks</td>
# <td class="center">1</td>
# <td class="winner">San Jose Sharks</td>
# <td class="center winner">8</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804180SJS.html">Game 4, April 18</a></td>
# <td>April 18</td>
# <td>Anaheim Ducks</td>
# <td class="center">1</td>
# <td class="winner">San Jose Sharks</td>
# <td class="center winner">2</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804120ANA.html">Game 1, April 12</a>
# <a href="/boxscores/201804140ANA.html">Game 2, April 14</a>
# <a href="/boxscores/201804160SJS.html">Game 3, April 16</a>
# <a href="/boxscores/201804180SJS.html">Game 4, April 18</a>
# <span class="tooltip opener" data-id="s3">First Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804110WPG.html">Game 1, April 11</a></td>
# <td>April 11</td>
# <td>Minnesota Wild</td>
# <td class="center">2</td>
# <td class="winner">Winnipeg Jets</td>
# <td class="center winner">3</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804130WPG.html">Game 2, April 13</a></td>
# <td>April 13</td>
# <td>Minnesota Wild</td>
# <td class="center">1</td>
# <td class="winner">Winnipeg Jets</td>
# <td class="center winner">4</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804150MIN.html">Game 3, April 15</a></td>
# <td>April 15</td>
# <td>Winnipeg Jets</td>
# <td class="center">2</td>
# <td class="winner">Minnesota Wild</td>
# <td class="center winner">6</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804170MIN.html">Game 4, April 17</a></td>
# <td>April 17</td>
# <td class="winner">Winnipeg Jets</td>
# <td class="center winner">2</td>
# <td>Minnesota Wild</td>
# <td class="center">0</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804200WPG.html">Game 5, April 20</a></td>
# <td>April 20</td>
# <td>Minnesota Wild</td>
# <td class="center">0</td>
# <td>Winnipeg Jets</td>
# <td class="center">5</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804110WPG.html">Game 1, April 11</a>
# <a href="/boxscores/201804130WPG.html">Game 2, April 13</a>
# <a href="/boxscores/201804150MIN.html">Game 3, April 15</a>
# <a href="/boxscores/201804170MIN.html">Game 4, April 17</a>
# <a href="/boxscores/201804200WPG.html">Game 5, April 20</a>
# <span class="tooltip opener" data-id="s2">First Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804110VEG.html">Game 1, April 11</a></td>
# <td>April 11</td>
# <td>Los Angeles Kings</td>
# <td class="center">0</td>
# <td>Vegas Golden Knights</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804130VEG.html">Game 2, April 13</a></td>
# <td>April 13</td>
# <td>Los Angeles Kings</td>
# <td class="center">1</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">2</td>
# <td class="center">
#
# 			(2OT)
#
# 		</td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804150LAK.html">Game 3, April 15</a></td>
# <td>April 15</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">3</td>
# <td>Los Angeles Kings</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804170LAK.html">Game 4, April 17</a></td>
# <td>April 17</td>
# <td class="winner">Vegas Golden Knights</td>
# <td class="center winner">1</td>
# <td>Los Angeles Kings</td>
# <td class="center">0</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804110VEG.html">Game 1, April 11</a>
# <a href="/boxscores/201804130VEG.html">Game 2, April 13</a>
# <a href="/boxscores/201804150LAK.html">Game 3, April 15</a>
# <a href="/boxscores/201804170LAK.html">Game 4, April 17</a>
# <span class="tooltip opener" data-id="s1">First Round</span>
# <table width="100%">
# <tr>
# <td><a href="/boxscores/201804120NSH.html">Game 1, April 12</a></td>
# <td>April 12</td>
# <td>Colorado Avalanche</td>
# <td class="center">2</td>
# <td class="winner">Nashville Predators</td>
# <td class="center winner">5</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804140NSH.html">Game 2, April 14</a></td>
# <td>April 14</td>
# <td>Colorado Avalanche</td>
# <td class="center">4</td>
# <td class="winner">Nashville Predators</td>
# <td class="center winner">5</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804160COL.html">Game 3, April 16</a></td>
# <td>April 16</td>
# <td>Nashville Predators</td>
# <td class="center">3</td>
# <td class="winner">Colorado Avalanche</td>
# <td class="center winner">5</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804180COL.html">Game 4, April 18</a></td>
# <td>April 18</td>
# <td class="winner">Nashville Predators</td>
# <td class="center winner">3</td>
# <td>Colorado Avalanche</td>
# <td class="center">2</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804200NSH.html">Game 5, April 20</a></td>
# <td>April 20</td>
# <td class="winner">Colorado Avalanche</td>
# <td class="center winner">2</td>
# <td>Nashville Predators</td>
# <td class="center">1</td>
# <td class="center">
# </td>
# </tr>
# <tr>
# <td><a href="/boxscores/201804220COL.html">Game 6, April 22</a></td>
# <td>April 22</td>
# <td class="winner">Nashville Predators</td>
# <td class="center winner">5</td>
# <td>Colorado Avalanche</td>
# <td class="center">0</td>
# <td class="center">
# </td>
# </tr>
# </table>
#
#
# <a href="/boxscores/201804120NSH.html">Game 1, April 12</a>
# <a href="/boxscores/201804140NSH.html">Game 2, April 14</a>
# <a href="/boxscores/201804160COL.html">Game 3, April 16</a>
# <a href="/boxscores/201804180COL.html">Game 4, April 18</a>
# <a href="/boxscores/201804200NSH.html">Game 5, April 20</a>
# <a href="/boxscores/201804220COL.html">Game 6, April 22</a>
