# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import urllib3
import requests
import time

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
base_url = 'https://www.hockey-reference.com/teams/'

# %%
def get_page(url):
    page = urlopen(base_url)
    soup = BeautifulSoup(page, 'lxml')
    file = open('hockey-reference_urls.txt', 'w')
    file.write(str(soup))
    file.close()

def get_team_links(url):
    page = urlopen(url)
    soup = BeautifulSoup(page, 'lxml')

# %%
get_page(base_url)

# %%
with open('hockey-reference_urls.txt', 'r') as file:
    for line in file:
        line = line.strip()

# %%
page = open("hockey-reference_urls.txt", 'r')
soup = BeautifulSoup(page, "lxml")
div = soup.find('div', {'class': 'overthrow table_container'})

# %%
team_links = []
links = div.find_all('a')
for link in links:
    team_links.append(link.get('href'))

# %%
len(team_links)
# Out:
# 31

# %%
def get_team_table(url):
    res = requests.get(url)
    goalie_soup = BeautifulSoup(res.content, 'lxml')
    team_name = goalie_soup.find('h1', {'itemprop': 'name'}).find_all('span')[1].text
    table = goalie_soup.find('div', {'id': 'all_goalies'}).find('table', {'id': 'goalies'}).find('tbody')
    team_stats = []
    for row in table.find_all('tr'):
        players = {}
        for element in row:
            players['Player'] = row.find('a').text
            players['Age'] = row.find('td', {'data-stat': 'age'}).text
            players['Games Played'] = row.find('td', {'data-stat': 'games_goalie'}).text
            players['Games Started'] = row.find('td', {'data-stat': 'starts_goalie'}).text
            players['Wins'] = row.find('td', {'data-stat': 'wins_goalie'}).text
            players['Losses'] = row.find('td', {'data-stat': 'losses_goalie'}).text
            players['Ties OT Losses'] = row.find('td', {'data-stat': 'ties_goalie'}).text
            players['Goals Against'] = row.find('td', {'data-stat': 'goals_against'}).text
            players['Shots Against'] = row.find('td', {'data-stat': 'shots_against'}).text
            players['Saves'] = row.find('td', {'data-stat': 'saves'}).text
            players['Save Percentage'] = row.find('td', {'data-stat': 'save_pct'}).text
            players['Goals Against Average'] = row.find('td', {'data-stat': 'goals_against_avg'}).text
            players['Shutouts'] = row.find('td', {'data-stat': 'shutouts'}).text
            players['Minutes'] = row.find('td', {'data-stat': 'min_goalie'}).text
            players['Quality Starts'] = row.find('td', {'data-stat': 'quality_starts_goalie'}).text
            players['Quality Start Percentage'] = row.find('td', {'data-stat': 'quality_start_goalie_pct'}).text
            players['Really Bad Starts'] = row.find('td', {'data-stat': 'really_bad_starts_goalie'}).text
            players['GA Pct -'] = row.find('td', {'data-stat': 'ga_pct_minus'}).text
            players['Goals Saved Above Average'] = row.find('td', {'data-stat': 'gs_above_avg'}).text
            players['Adjusted GAA'] = row.find('td', {'data-stat': 'goals_against_avg_adjusted'}).text
            players['Goalie Point Shares'] = row.find('td', {'data-stat': 'gps'}).text
            players['Team'] = team_name
        team_stats.append(players)
    return team_stats

# %%
team_year = get_team_table('https://www.hockey-reference.com/teams/ANA/2018.html')

# %%
base_url = 'https://www.hockey-reference.com'
teams = team_links
years = ['2011.html']
year_df = pd.DataFrame()
for team in teams:
    try:
        for year in years:
            url = base_url + team + year
            team_year = get_team_table(url)
            team_df = pd.DataFrame(team_year)
            year_df = pd.concat([year_df, team_df], axis=0)
            year_df.reset_index(drop=True, inplace=True)
            time.sleep(3)
    except:
        continue

# %%
year_df
# Out:
#    Adjusted GAA Age GA Pct - Games Played Games Started Goalie Point Shares  \
# 0          2.74  26       95           43            37                 7.0
# 1          2.46  22       94           40            38                 6.5
# 2          3.20  29                     9             7                 0.9
# 3          3.07  28       99           64            62                11.1
# 4          3.24  31      108           24            20                 3.2
# 5          2.83  29       94           45            40                 8.2
# 6          3.13  22      102           20            20                 3.2
# 7          2.94  24       89           21            21                 4.5
# 8          5.00  23                     1             1                 0.0
# 9          3.13  29      107           37            37                 5.4
# 10         4.22  33      142           26            23                 1.1
# 11         3.31  24      115           22            19                 2.5
# 12         4.13  37                     4             3                 0.2
# 13         2.88  31      107           52            51                 7.0
# 14         3.37  28      116           34            31                 3.9
# 15         2.82  31       90           58            58                12.0
# 16         3.08  27      100           29            24                 4.6
# 17         1.52  34                     1             0                 0.2
# 18         3.36  27      101           57            57                 9.9
# 19         3.04  23       92           20            13                 3.6
# 20         2.91  29       91           14            12                 2.5
# 21         3.25  23                     1             0                -0.1
# 22         3.09  21       95           31            30                 6.3
# 23         3.29  27      109           37            37                 5.3
# 24         3.95  32      130           18            12                 1.2
# 25         3.70  23                     4             3                 0.5
# 26         3.32  32      110           43            39                 5.5
# 27         3.19  32      111           48            43                 5.9
# 28         2.78  23       93           54            49                 9.5
# 29         3.34  31      110           37            33                 4.8
# ..          ...  ..      ...          ...           ...                 ...
# 60         3.17  27      101           24            21                 4.2
# 61         0.00  21                     1             0                 0.2
# 62         4.14  23                     1             1                 0.2
# 63         3.01  27       97           54            53                10.0
# 64         2.70  27       89           32            29                 6.4
# 65         2.72  31       93           58            58                11.0
# 66         2.40  21       83           13            13                 2.7
# 67         3.36  28       98           14            11                 2.5
# 68         2.69  26       97           65            65                10.8
# 69         1.99  27                     8             8                 1.8
# 70         3.47  28                    13             9                 0.6
# 71         2.81  25       94           47            44                 8.2
# 72         2.47  30       82           42            38                 8.6
# 73         4.69  22                     1             0                -0.1
# 74         2.46  24                     1             0                 0.0
# 75         3.44  25                     3             0                 0.2
# 76         2.44  29       86           61            60                12.2
# 77         3.29  21      105           24            21                 3.5
# 78         1.00  23                     1             1                 0.4
# 79         3.44  27      109           38            36                 5.6
# 80         2.99  27       96           32            29                 5.8
# 81         3.63  22      126           17            17                 1.5
# 82         3.23  35       98           51            51                 9.9
# 83         3.28  26      100           33            30                 5.9
# 84         4.01  28                     1             1                 0.1
# 85         2.62  26       92           66            66                12.1
# 86         2.75  24       97           22            16                 3.3
# 87         2.80  22       96           26            26                 4.3
# 88         3.32  28      113           33            31                 4.3
# 89         3.40  25      109           30            25                 4.0
#
#    Goals Against Goals Against Average Goals Saved Above Average Losses ...   \
# 0             88                  2.30                      4.46      9 ...
# 1             79                  2.07                      5.46     13 ...
# 2             16                  2.69                                3 ...
# 3            157                  2.56                      0.85     22 ...
# 4             57                  2.72                     -4.04      9 ...
# 5            102                  2.36                      6.13     16 ...
# 6             49                  2.60                     -0.89     10 ...
# 7             48                  2.47                      5.98      9 ...
# 8              4                  4.00                                1 ...
# 9             94                  2.63                     -5.96     18 ...
# 10            79                  3.51                    -23.32     11 ...
# 11            55                  2.76                     -6.98      9 ...
# 12            13                  3.35                                2 ...
# 13           122                  2.41                     -7.65     17 ...
# 14            90                  2.81                    -12.52     14 ...
# 15           131                  2.37                     15.27     18 ...
# 16            67                  2.58                     -0.25      8 ...
# 17             1                  1.52                                0 ...
# 18           148                  2.81                     -2.07     25 ...
# 19            42                  2.56                      3.89      6 ...
# 20            29                  2.41                      2.84      8 ...
# 21             1                  3.25                                0 ...
# 22            78                  2.60                      4.50     11 ...
# 23            97                  2.75                     -7.69     19 ...
# 24            46                  3.30                    -10.50      7 ...
# 25             9                  3.03                                3 ...
# 26           105                  2.76                     -9.56     10 ...
# 27           118                  2.67                    -11.91     13 ...
# 28           115                  2.33                      8.29     16 ...
# 29            92                  2.80                     -8.65     14 ...
# ..           ...                   ...                       ...    ... ...
# 60            61                  2.65                     -0.38     11 ...
# 61             0                  0.00                                0 ...
# 62             3                  3.10                                1 ...
# 63           132                  2.51                      4.40     19 ...
# 64            69                  2.27                      8.31      8 ...
# 65           132                  2.29                      9.76     17 ...
# 66            25                  2.00                      5.23      2 ...
# 67            34                  2.79                      0.74      7 ...
# 68           143                  2.27                      4.64     23 ...
# 69            13                  1.62                                2 ...
# 70            33                  2.94                                5 ...
# 71           101                  2.35                      6.28     15 ...
# 72            78                  2.07                     16.76      8 ...
# 73             1                  4.69                                0 ...
# 74             1                  2.46                                0 ...
# 75             4                  2.75                                1 ...
# 76           123                  2.06                     19.36     21 ...
# 77            58                  2.76                     -3.00     10 ...
# 78             1                  1.00                                0 ...
# 79           103                  2.88                     -8.15     21 ...
# 80            75                  2.49                      3.33     12 ...
# 81            49                  3.02                    -10.18      9 ...
# 82           137                  2.70                      2.12     24 ...
# 83            84                  2.73                      0.12     14 ...
# 84             3                  3.01                                0 ...
# 85           141                  2.20                     12.43      9 ...
# 86            43                  2.32                      1.53      9 ...
# 87            56                  2.34                      2.15     11 ...
# 88            88                  2.78                     -9.84     13 ...
# 89            75                  2.84                     -6.46     15 ...
#
#    Quality Start Percentage Quality Starts Really Bad Starts Save Percentage  \
# 0                      .649             24                 5            .919
# 1                      .553             21                 3            .920
# 2                      .429              3                 3            .909
# 3                      .548             34                10            .915
# 4                      .450              9                 2            .908
# 5                      .575             23                 3            .920
# 6                      .600             12                 4            .913
# 7                      .619             13                 3            .924
# 8                      .000              0                 0            .867
# 9                      .541             20                 4            .909
# 10                     .304              7                 8            .879
# 11                     .474              9                 3            .902
# 12                     .667              2                 1            .881
# 13                     .451             23                 7            .909
# 14                     .452             14                 7            .901
# 15                     .690             40                 9            .924
# 16                     .542             13                 5            .915
# 17                                       0                 0            .941
# 18                     .439             25                10            .914
# 19                     .615              8                 1            .922
# 20                     .583              7                 2            .922
# 21                                       0                 0            .667
# 22                     .533             16                 1            .920
# 23                     .486             18                 8            .908
# 24                     .250              3                 3            .890
# 25                     .333              1                 0            .907
# 26                     .513             20                 5            .906
# 27                     .442             19                 8            .905
# 28                     .633             31                 5            .921
# 29                     .485             16                 6            .906
# ..                      ...            ...               ...             ...
# 60                     .619             13                 1            .914
# 61                                       0                 0           1.000
# 62                     .000              0                 0            .912
# 63                     .528             28                 5            .918
# 64                     .586             17                 3            .924
# 65                     .569             33                 5            .921
# 66                     .769             10                 0            .930
# 67                     .636              7                 3            .917
# 68                     .554             36                 9            .918
# 69                     .625              5                 1            .938
# 70                     .222              2                 5            .884
# 71                     .591             26                 6            .920
# 72                     .684             26                 6            .930
# 73                                       0                 0            .750
# 74                                       0                 0            .833
# 75                                       0                 0            .909
# 76                     .617             37                 4            .926
# 77                     .333              7                 3            .910
# 78                    1.000              1                 0            .969
# 79                     .528             19                 8            .908
# 80                     .586             17                 5            .918
# 81                     .353              6                 4            .893
# 82                     .490             25                 2            .916
# 83                     .567             17                 4            .915
# 84                     .000              0                 0            .903
# 85                     .636             42                 6            .922
# 86                     .438              7                 2            .918
# 87                     .538             14                 6            .918
# 88                     .452             14                 6            .904
# 89                     .360              9                 3            .907
#
#    Saves Shots Against Shutouts                   Team Ties OT Losses Wins
# 0    998          1086        3          Anaheim Ducks              7   22
# 1    913           992        4          Anaheim Ducks              4   21
# 2    159           175        1          Anaheim Ducks              0    3
# 3   1697          1854        4          Boston Bruins              8   31
# 4    565           622        1          Boston Bruins              1   11
# 5   1168          1270        1         Buffalo Sabres              4   22
# 6    516           565        0         Buffalo Sabres              2    8
# 7    586           634        1         Buffalo Sabres              5    5
# 8     26            30        0         Buffalo Sabres              0    0
# 9    940          1034        1         Calgary Flames              1   17
# 10   575           654        1         Calgary Flames              1    9
# 11   509           564        1         Calgary Flames              5    7
# 12    96           109        0         Calgary Flames              0    2
# 13  1221          1343        1    Carolina Hurricanes             10   23
# 14   820           910        2    Carolina Hurricanes              6   12
# 15  1587          1718        7     Chicago Blackhawks              5   35
# 16   717           784        1     Chicago Blackhawks              4   12
# 17    16            17        0     Chicago Blackhawks              0    0
# 18  1566          1714        2     Colorado Avalanche              3   27
# 19   497           539        1     Colorado Avalanche              1    7
# 20   345           374        2     Colorado Avalanche              0    5
# 21     2             3        0     Colorado Avalanche              0    0
# 22   891           969        0  Columbus Blue Jackets              4   16
# 23   952          1049        1  Columbus Blue Jackets              1   15
# 24   371           417        0  Columbus Blue Jackets              3    2
# 25    88            97        0  Columbus Blue Jackets              0    1
# 26  1016          1121        2           Dallas Stars              2   25
# 27  1128          1246        3           Dallas Stars              7   25
# 28  1333          1448        4      Detroit Red Wings              6   27
# 29   887           979        2      Detroit Red Wings              5   14
# ..   ...           ...      ...                    ...            ...  ...
# 60   651           712        1        Ottawa Senators              4    7
# 61    11            11        0        Ottawa Senators              0    0
# 62    31            34        0        Ottawa Senators              0    0
# 63  1470          1602        4    Philadelphia Flyers             10   23
# 64   839           908        3    Philadelphia Flyers              4   18
# 65  1533          1665        5    Pittsburgh Penguins              6   35
# 66   330           355        1    Pittsburgh Penguins              1    9
# 67   374           408        0    Pittsburgh Penguins              1    4
# 68  1591          1734        6        San Jose Sharks              4   37
# 69   195           208        3        San Jose Sharks              0    6
# 70   252           285        0        San Jose Sharks              2    3
# 71  1159          1260        6        St. Louis Blues              3   26
# 72  1035          1113        4        St. Louis Blues              6   23
# 73     3             4        0        St. Louis Blues              0    0
# 74     5             6        0        St. Louis Blues              0    0
# 75    40            44        0        St. Louis Blues              0    0
# 76  1549          1672        6    Tampa Bay Lightning              4   35
# 77   588           646        1    Tampa Bay Lightning              0   11
# 78    31            32        0    Tampa Bay Lightning              1    0
# 79  1011          1114        3    Toronto Maple Leafs              3   12
# 80   845           920        0    Toronto Maple Leafs              7   11
# 81   407           456        1    Toronto Maple Leafs              1    6
# 82  1497          1634        1      Vancouver Canucks              9   17
# 83   904           988        0      Vancouver Canucks              4   13
# 84    28            31        0      Vancouver Canucks              0    1
# 85  1661          1802        3    Washington Capitals              7   48
# 86   480           523        0    Washington Capitals              1    8
# 87   627           683        2          Winnipeg Jets              1   13
# 88   830           918        1          Winnipeg Jets              4   13
# 89   730           805        0          Winnipeg Jets              3    9
#
# [90 rows x 22 columns]

# %%
year_df.to_csv('2011 goalie stats.csv')
